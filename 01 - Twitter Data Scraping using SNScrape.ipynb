# %%
conda install -c anaconda git
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\nehad\AppData\Local\Temp\pip-req-build-_1txtup8'
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\nehad\appdata\local\temp\pip-req-build-_1txtup8
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev138+ga6b6f3f-py3-none-any.whl size=52210 sha256=49fce8d3be1d21467938b22080743ed7efb37289811a4e9474d46a285d731fdc
#   Stored in directory: C:\Users\nehad\AppData\Local\Temp\pip-ephem-wheel-cache-49lbl2xh\wheels\92\42\87\33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# ...
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.3.5.dev137+g5e829e2
#     Uninstalling snscrape-0.3.5.dev137+g5e829e2:
#       Successfully uninstalled snscrape-0.3.5.dev137+g5e829e2
# ...

# %%
import os
import pandas as pd
from datetime import datetime

# %%
tweets_master = pd.DataFrame()

# %%
#Text search
tweet_count = 100
text_query = "GME"
since_date = "2021-10-10"
until_date = "2021-10-11" 

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

tweets_master = tweets_master.append(tweets_df2)

# Displays first 5 entries from dataframe
tweets_df2.head()
print(len(tweets_master))
# Out:
# 1000

# %%
pd.set_option("display.max_colwidth", None)
df = pd.DataFrame(tweets_master)

df
# Out:
#                              _type  \
# 0   snscrape.modules.twitter.Tweet
# 1   snscrape.modules.twitter.Tweet
# 2   snscrape.modules.twitter.Tweet
# 3   snscrape.modules.twitter.Tweet
# 4   snscrape.modules.twitter.Tweet
# ..                             ...
# 95  snscrape.modules.twitter.Tweet
# 96  snscrape.modules.twitter.Tweet
# 97  snscrape.modules.twitter.Tweet
# 98  snscrape.modules.twitter.Tweet
# 99  snscrape.modules.twitter.Tweet
#
#                                                                url  \
# 0   https://twitter.com/spacemonkey9006/status/1444089626159898626
# 1       https://twitter.com/langliblade/status/1444089504734851072
# 2          https://twitter.com/OrbitofA/status/1444089489584898048
# 3           https://twitter.com/GME_Gun/status/1444089487638757381
# 4   https://twitter.com/ConvexityCowboy/status/1444089442835341312
# ..                                                             ...
# ...

# %%
#tweets_master.drop_duplicates()

# %%
pd.set_option("display.max_colwidth", None)
df['content']
# Out:
# 0                                                                                                                                                                                                                                GME AMC Tradesloshing Fridaysh https://t.co/r5uXjTxEVX via @YouTube
# 1                                                                                                                                                                                                                                                          HWTAS WRONF WITH THIS Gme icabt rbenemrkd
# 2     For those who have not bookmarked this yet, now is your chance. This the library of due diligence (DD) to date. It has the best DD on the stonks, and everything related. \nhttps://t.co/GITQ8wObVr\n🦍\n#amc\n#gme\n#amcsqeeze\n#gmesqueeze\n#apesnotleaving\n#KenGriffinLied\n#CitadelScandal
# ...

# %%
# Export dataframe into a CSV
tweets_master.to_csv('tweets_oct21_base.csv', sep=',', index=False)
